# %%
import os
import re
import time
import frontmatter

def update_front_matter(
    file, 
    update_modify_time=False, 
    add_tag:list=None, clear_all_tag=False, del_tag:list=None, 
    add_meta:dict=None, del_meta:list=None
):
    """修改yamal格式的frontmatter
    file: 要处理的文件路径
    update_modify_time: 是否更新最后编辑时间
    add_tag: 要添加的标签列表
    clear_all_tag: 是否清除所有tag
    del_tag: 删除指定列表的标签
    add_meta: 添加元数据项目
    del_meta: 删除指定列表的元数据项目
    """
    
    is_write = False
    
    with open(file, 'r', encoding='utf-8') as f:
        post = frontmatter.loads(f.read())
    
    # 更新文件修改时间
    if update_modify_time:
        if not post.metadata.get('modify_date', None):
            timeArray = time.localtime((os.path.getmtime(file)))
            post['modify_date'] = time.strftime("%Y-%m-%d %H:%M", timeArray)
            print(f'更新后修改时间为: {time.strftime("%Y-%m-%d %H:%M", timeArray)}')
            is_write = True
    
    # 标签操作
    exist_tags = post.get("tags", [])
    if isinstance(exist_tags, str):
        exist_tags = [tag for tag in exist_tags.replace(',',' ').split(" ") if tag != ""]
    new_tags = exist_tags.copy()
    
    if add_tag is not None:
        new_tags = new_tags + add_tag
    if del_tag is not None:
        new_tags = [tag for tag in new_tags if tag not in del_tag]
    if clear_all_tag:
        new_tags = []
    
    if set(new_tags) != set(exist_tags):
        new_tags = list(set(new_tags))
        new_tags.sort()
        post['tags'] = new_tags
        print(f'当前文件tag有: {exist_tags}, 修改后文件标签有: {new_tags}')
        is_write = True
    
    # 元数据项目操作
    exist_keys = post.metadata.keys()

    if add_meta is not None:
        post.metadata.append(add_meta)
    if del_meta is not None:
        for meta in del_meta:
            post.metadata.pop(meta, None)
    
    new_keys = post.metadata.keys()
    print(exist_keys)
    print(new_keys)
    if set(new_keys)!=set(exist_keys):
        print(f'当前文件元数据项目有: {exist_keys}, 修改后文件元数据项目有: {new_keys}')
        is_write = True
    
    # 标签写入
    if is_write:
        with open(file, 'w', encoding='utf-8') as f:
            f.write(frontmatter.dumps(post))


def list_all_md(root_path, ignore_dirs=[]):
    """
    生成md文件列表
    """
    files = []
    default_dirs = [".git", ".obsidian", ".config", ".stfolder", ".trash"]
    ignore_dirs.extend(default_dirs)

    for parent, dirs, filenames in os.walk(root_path):
        dirs[:] = [d for d in dirs if not d in ignore_dirs]
        filenames = [f for f in filenames if not f[0] == '.']
        for file in filenames:
            if file.endswith(".md"):
                files.append(os.path.join(parent, file))
    return files


if __name__ == "__main__":

    files = list_all_md(r'C:\Users\Tking\Documents\MyCode\MyNote\编程\Python\源码详解')
    for file in files:
        
        print("---------------------------------------------------------------")
        print('当前文件: ', file)
        
        update_front_matter(file, del_meta=['tags','author','Update Time','Last Edit Time'])

# %%
with open(files[0], 'r', encoding='utf-8') as f:
    post = frontmatter.loads(f.read())

# %%
post.metadata.keys()
# Out:
# dict_keys(['tags'])

# %%
files
# Out:
# ['C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\01 开篇词：为什么要钻研 Python 源码？.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\02 小菜成长之路，警惕沦为 API 调用侠.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\03 Python 对象模型概述.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\04 揭开对象神秘的面纱.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\05 从创建到销毁，对象的生命周期.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\06 小试牛刀，解剖浮点对象 float.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\07 int 对象，永不溢出的整数.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\08 int 源码解析：如何实现大整数运算？.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\09 bytes 对象，不可变的字节序列.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\10 str 对象，统一的 Unicode 字符串.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\11 list 对象，容量自适应的数组式容器.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\12 list 源码解析：动态数组精讲.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\13 dict 对象，高效的关联式容器.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\14 dict 哈希表高级知识精讲.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\15 和面试官畅谈内建对象背后的算法思想.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\16 最佳实践：灵活运用内建容器，提高开发效率.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\17 开发实战：基于最小堆设计任务调度系统.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\18 Python 程执行过程与字节码.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\19 面试必问概念精讲：作用域与名字空间.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\20 原来虚拟机是一颗软件 CPU.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\21 GIL 全局锁，束缚Python的紧箍圈.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\22 模块动态加载， import 背后哪些事儿.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\23 用字节码彻底征服面试官.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\24 函数对象诞生记.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\25 函数调用与虚拟机软件栈.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\26 面试必问：嵌套函数、闭包与装饰器.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\27 高阶函数与函数式编程.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\28 高级技巧：令人叹为观止的装饰器.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\29 函数相关面试题精讲.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\30 类对象诞生记.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\31 类继承机制与属性查找.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\32 属性描述符如何影响属性行为.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\33 高阶编程：魔术方法应用实战.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\34 metaclass 在程序开发中的妙用.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\35 奇门武动：如何实现代码热更新.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\36 类和继承相关面试题精讲.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\37 重新认识生成器 generator.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\38 字节码解读 generator 运行机制.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\39 再造轮子：手把手教你设计协程库.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\40 工程实践：用 asyncio 协程构建高并发应用.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\41 小块内存池如何优化内存分配效率？.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\42 引用计数的致命缺陷与应对之策.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\43 全面解读 Python 垃圾回收机制.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\44 妙手回春：内存泄露诊断案例分析.md',
#  'C:\\Users\\Tking\\Documents\\MyCode\\MyNote\\编程\\Python\\源码详解\\45 读懂 Python，才能更 Pythonic！.md']
